# %%
import pandas as pd
import matplotlib.pyplot as plt
train = pd.read_csv ('C:\\Users\\echols\\Documents\\Data Analysis\\Panda Training\\pandas_for_everyone-master\\data\\train.csv')

# %%
train
# Out:
#                         Patient  Weeks   FVC    Percent  Age   Sex  \
# 0     ID00007637202177411956430     -4  2315  58.253649   79  Male
# 1     ID00007637202177411956430      5  2214  55.712129   79  Male
# 2     ID00007637202177411956430      7  2061  51.862104   79  Male
# 3     ID00007637202177411956430      9  2144  53.950679   79  Male
# 4     ID00007637202177411956430     11  2069  52.063412   79  Male
# ...                         ...    ...   ...        ...  ...   ...
# 1544  ID00426637202313170790466     13  2712  66.594637   73  Male
# 1545  ID00426637202313170790466     19  2978  73.126412   73  Male
# 1546  ID00426637202313170790466     31  2908  71.407524   73  Male
# 1547  ID00426637202313170790466     43  2975  73.052745   73  Male
# 1548  ID00426637202313170790466     59  2774  68.117081   73  Male
#
#      SmokingStatus
# 0        Ex-smoker
# 1        Ex-smoker
# 2        Ex-smoker
# 3        Ex-smoker
# 4        Ex-smoker
# ...            ...
# ...

# %%
train.columns
# Out:
# Index(['Patient', 'Weeks', 'FVC', 'Percent', 'Age', 'Sex', 'SmokingStatus'], dtype='object')

# %%
train.describe()
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1549 entries, 0 to 1548
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Patient        1549 non-null   object
#  1   Weeks          1549 non-null   int64
#  2   FVC            1549 non-null   int64
#  3   Percent        1549 non-null   float64
#  4   Age            1549 non-null   int64
#  5   Sex            1549 non-null   object
#  6   SmokingStatus  1549 non-null   object
# dtypes: float64(1), int64(3), object(3)
# memory usage: 66.6+ KB

# %%
train.index
# Out:
# RangeIndex(start=0, stop=1549, step=1)

# %%
train.plot()

# %%
train.plot.hist()

# %%
len(train)
# Out:
# 1549

# %%
train.mean()
# Out:
# Weeks        31.861846
# FVC        2690.479019
# Percent      77.672654
# Age          67.188509
# dtype: float64

# %%
train.sum()
# Out:
# Patient          ID00007637202177411956430ID0000763720217741195...
# Weeks                                                        49354
# FVC                                                        4167552
# Percent                                                     120315
# Age                                                         104075
# Sex              MaleMaleMaleMaleMaleMaleMaleMaleMaleMaleMaleMa...
# SmokingStatus    Ex-smokerEx-smokerEx-smokerEx-smokerEx-smokerE...
# dtype: object

# %%
train.head()
# Out:
#                      Patient  Weeks   FVC    Percent  Age   Sex SmokingStatus
# 0  ID00007637202177411956430     -4  2315  58.253649   79  Male     Ex-smoker
# 1  ID00007637202177411956430      5  2214  55.712129   79  Male     Ex-smoker
# 2  ID00007637202177411956430      7  2061  51.862104   79  Male     Ex-smoker
# 3  ID00007637202177411956430      9  2144  53.950679   79  Male     Ex-smoker
# 4  ID00007637202177411956430     11  2069  52.063412   79  Male     Ex-smoker

# %%
train.tail()
# Out:
#                         Patient  Weeks   FVC    Percent  Age   Sex  \
# 1544  ID00426637202313170790466     13  2712  66.594637   73  Male
# 1545  ID00426637202313170790466     19  2978  73.126412   73  Male
# 1546  ID00426637202313170790466     31  2908  71.407524   73  Male
# 1547  ID00426637202313170790466     43  2975  73.052745   73  Male
# 1548  ID00426637202313170790466     59  2774  68.117081   73  Male
#
#      SmokingStatus
# 1544  Never smoked
# 1545  Never smoked
# 1546  Never smoked
# 1547  Never smoked
# 1548  Never smoked

# %%
train[train['Sex'] == 'Male']
# Out:
#                         Patient  Weeks   FVC    Percent  Age   Sex  \
# 0     ID00007637202177411956430     -4  2315  58.253649   79  Male
# 1     ID00007637202177411956430      5  2214  55.712129   79  Male
# 2     ID00007637202177411956430      7  2061  51.862104   79  Male
# 3     ID00007637202177411956430      9  2144  53.950679   79  Male
# 4     ID00007637202177411956430     11  2069  52.063412   79  Male
# ...                         ...    ...   ...        ...  ...   ...
# 1544  ID00426637202313170790466     13  2712  66.594637   73  Male
# 1545  ID00426637202313170790466     19  2978  73.126412   73  Male
# 1546  ID00426637202313170790466     31  2908  71.407524   73  Male
# 1547  ID00426637202313170790466     43  2975  73.052745   73  Male
# 1548  ID00426637202313170790466     59  2774  68.117081   73  Male
#
#      SmokingStatus
# 0        Ex-smoker
# 1        Ex-smoker
# 2        Ex-smoker
# 3        Ex-smoker
# 4        Ex-smoker
# ...            ...
# ...

# %%
train.shape
# Out:
# (1549, 7)

# %%
train[train['Sex'] == 'Female']
# Out:
#                         Patient  Weeks   FVC    Percent  Age     Sex  \
# 62    ID00019637202178323708467     13  2100  92.858722   83  Female
# 63    ID00019637202178323708467     14  2047  90.515145   83  Female
# 64    ID00019637202178323708467     16  2001  88.481097   83  Female
# 65    ID00019637202178323708467     18  2054  90.824674   83  Female
# 66    ID00019637202178323708467     20  2002  88.525315   83  Female
# ...                         ...    ...   ...        ...  ...     ...
# 1455  ID00405637202308359492977     12  1603  63.525402   61  Female
# 1456  ID00405637202308359492977     18  1584  62.772450   61  Female
# 1457  ID00405637202308359492977     31  1523  60.355076   61  Female
# 1458  ID00405637202308359492977     42  1412  55.956250   61  Female
# 1459  ID00405637202308359492977     58  1547  61.306174   61  Female
#
#      SmokingStatus
# 62       Ex-smoker
# 63       Ex-smoker
# 64       Ex-smoker
# 65       Ex-smoker
# 66       Ex-smoker
# ...

# %%
train[train['SmokingStatus'] == 'Ex-smoker']
# Out:
#                         Patient  Weeks   FVC    Percent  Age   Sex  \
# 0     ID00007637202177411956430     -4  2315  58.253649   79  Male
# 1     ID00007637202177411956430      5  2214  55.712129   79  Male
# 2     ID00007637202177411956430      7  2061  51.862104   79  Male
# 3     ID00007637202177411956430      9  2144  53.950679   79  Male
# 4     ID00007637202177411956430     11  2069  52.063412   79  Male
# ...                         ...    ...   ...        ...  ...   ...
# 1535  ID00423637202312137826377     23  2661  64.027911   72  Male
# 1536  ID00423637202312137826377     30  2778  66.843118   72  Male
# 1537  ID00423637202312137826377     42  2516  60.538980   72  Male
# 1538  ID00423637202312137826377     53  2432  58.517806   72  Male
# 1539  ID00423637202312137826377     70  2578  62.030799   72  Male
#
#      SmokingStatus
# 0        Ex-smoker
# 1        Ex-smoker
# 2        Ex-smoker
# 3        Ex-smoker
# 4        Ex-smoker
# ...            ...
# ...

# %%
train[train['SmokingStatus'] == 'Never smoked']
# Out:
#                         Patient  Weeks   FVC     Percent  Age   Sex  \
# 36    ID00012637202177665765362     33  3418   93.726006   65  Male
# 37    ID00012637202177665765362     35  3759  103.076670   65  Male
# 38    ID00012637202177665765362     37  3276   89.832182   65  Male
# 39    ID00012637202177665765362     39  3443   94.411539   65  Male
# 40    ID00012637202177665765362     41  3268   89.612811   65  Male
# ...                         ...    ...   ...         ...  ...   ...
# 1544  ID00426637202313170790466     13  2712   66.594637   73  Male
# 1545  ID00426637202313170790466     19  2978   73.126412   73  Male
# 1546  ID00426637202313170790466     31  2908   71.407524   73  Male
# 1547  ID00426637202313170790466     43  2975   73.052745   73  Male
# 1548  ID00426637202313170790466     59  2774   68.117081   73  Male
#
#      SmokingStatus
# 36    Never smoked
# 37    Never smoked
# 38    Never smoked
# 39    Never smoked
# 40    Never smoked
# ...            ...
# ...

# %%
train[train['SmokingStatus'] == 'Currently smokes']
# Out:
#                         Patient  Weeks   FVC     Percent  Age     Sex  \
# 288   ID00082637202201836229724     19  2918   99.794802   49  Female
# 289   ID00082637202201836229724     27  2955  101.060192   49  Female
# 290   ID00082637202201836229724     29  2873   98.255814   49  Female
# 291   ID00082637202201836229724     31  2963  101.333789   49  Female
# 292   ID00082637202201836229724     33  2885   98.666211   49  Female
# ...                         ...    ...   ...         ...  ...     ...
# 1287  ID00355637202295106567614     34  4514  144.291011   65    Male
# 1288  ID00355637202295106567614     40  4762  152.218386   65    Male
# 1289  ID00355637202295106567614     52  4730  151.195499   65    Male
# 1290  ID00355637202295106567614     65  4791  153.145378   65    Male
# 1291  ID00355637202295106567614     82  4447  142.149342   65    Male
#
#          SmokingStatus
# 288   Currently smokes
# 289   Currently smokes
# 290   Currently smokes
# 291   Currently smokes
# ...

# %%
train_ages = train.groupby('Sex')['Age'].mean()

# %%
train_ages
# Out:
# Sex
# Female    66.683077
# Male      67.322712
# Name: Age, dtype: float64
